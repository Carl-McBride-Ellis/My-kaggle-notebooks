# %% [markdown]
# # Shakeup interactive scatterplot maker: [OSIC Pulmonary Fibrosis Progression](https://www.kaggle.com/c/osic-pulmonary-fibrosis-progression)
#
# This notebook is a *reductio* of the more detailed notebook [Meta Kaggle: Scatter Plot Competition Shake-up](https://www.kaggle.com/jtrotman/meta-kaggle-scatter-plot-competition-shake-up), written by [jtrotman](https://www.kaggle.com/jtrotman). Here we produce an individual shakeup scatter plot of the [OSIC Pulmonary Fibrosis Progression](https://www.kaggle.com/c/osic-pulmonary-fibrosis-progression) competition which finished recently.
#
# This notebook is easily adaptable to any future (or past) competition simply by using the pertinent `search_string`.

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
search_string = "OSIC"

# %% [markdown]
# Check that we have the correct competition:

# %%
comps = pd.read_csv('../input/meta-kaggle/Competitions.csv')
our_competition  = comps[comps['Title'].str.contains(search_string,na=False)]
pd.set_option('display.max_columns', None)
our_competition
# Out:
#          Id                                 Slug  \
# 3189  20604  osic-pulmonary-fibrosis-progression
#
#                                     Title                       Subtitle  \
# 3189  OSIC Pulmonary Fibrosis Progression  Predict lung function decline
#
#      HostSegmentTitle   ForumId  OrganizationId  CompetitionTypeId HostName  \
# 3189         Featured  777005.0          3745.0                  1      NaN
#
#               EnabledDate         DeadlineDate  \
# 3189  07/07/2020 17:00:16  10/06/2020 23:59:00
#
#      ProhibitNewEntrantsDeadlineDate TeamMergerDeadlineDate  \
# 3189             09/29/2020 23:59:00    09/29/2020 23:59:00
#
#      TeamModelDeadlineDate ModelSubmissionDeadlineDate  \
# 3189   10/30/2020 00:00:00                         NaN
#
#       FinalLeaderboardHasBeenVerified  HasKernels  OnlyAllowKernelSubmissions  \
# 3189                             True        True                        True
#
#       HasLeaderboard  LeaderboardPercentage  LeaderboardDisplayFormat  \
# 3189            True                      1                       0.0
#
#      EvaluationAlgorithmAbbreviation EvaluationAlgorithmName  \
# 3189            LaplaceLogLikelihood  Laplace Log Likelihood
#
#                          EvaluationAlgorithmDescription  \
# 3189  Laplace Log Likelihood. Metric values are nega...
#
#      EvaluationAlgorithmIsMax ValidationSetName ValidationSetValue  \
# 3189                     True               NaN                NaN
#
#       MaxDailySubmissions  NumScoredSubmissions  MaxTeamSize  BanTeamMergers  \
# 3189                    5                     2          5.0           False
#
#       EnableTeamModels  EnableSubmissionModelHashes  \
# 3189              True                        False
#
#       EnableSubmissionModelAttachments RewardType  RewardQuantity  NumPrizes  \
# 3189                             False        USD         55000.0          3
#
#       UserRankMultiplier  CanQualifyTiers  TotalTeams  TotalCompetitors  \
# 3189                 1.0             True        2097              2530
#
#       TotalSubmissions
# 3189             39082

# %% [markdown]
# And now the scatterplot

# %%
CompetitionId = our_competition["Id"].squeeze()
CompetitionIndex = our_competition.index.values.astype(int)[0]
all_teams = pd.read_csv('../input/meta-kaggle/Teams.csv')
teams = all_teams[all_teams['CompetitionId']==CompetitionId]
teams = teams.assign(Medal=teams.Medal.fillna(0).astype(int))
COLOR_DICT = {0: 'deepskyblue', 1: 'gold', 2: 'silver', 3: 'chocolate'}
MEDAL_NAMES = np.asarray(["None", "Gold", "Silver", "Bronze"])
MEDAL_COLORS = dict(zip(MEDAL_NAMES, COLOR_DICT.values()))
row = comps.loc[CompetitionIndex]
teams = teams.assign(Medal=MEDAL_NAMES[teams.Medal])
fig = px.scatter(teams,
                 title='Shakeup plot for: ' + row.Title,
                 x='PublicLeaderboardRank',
                 y='PrivateLeaderboardRank',
                 hover_name='TeamName',
                 hover_data=[
                     'ScoreFirstSubmittedDate',
                     'LastSubmissionDate',
                     'PublicLeaderboardSubmissionId',
                     'PrivateLeaderboardSubmissionId',
                     'Medal',
                     'MedalAwardDate',
                 ],
                 color='Medal',
                 color_discrete_map=MEDAL_COLORS)
fig.update_traces(marker=dict(size=5))
fig.update_layout(showlegend=False)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="00bf25b7-5283-457a-b7e9-f1233f58690a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00bf25b7-5283-457a-b7e9-f1233f58690a")) {                    Plotly.newPlot(                        "00bf25b7-5283-457a-b7e9-f1233f58690a",                        [{"customdata": [[null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, "10/06/2020", 17399396.0, 17459197.0, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, "07/14/2020", 16512279.0, 16489828.0, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, "10/06/2020", 17463844.0, 17463844.0, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, "10/03/2020", 17417221.0, 17417221.0, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, "07/08/2020", 16435831.0, 16435831.0, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, "07/07/2020", 16431170.0, 16431170.0, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, "07/08/2020", 16435507.0, 16435507.0, "None", null], [null, null, null, null, "None", null], [null, "09/28/2020", 17353191.0, 17353191.0, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null, null, null, "None", null], [null, null,  ...
